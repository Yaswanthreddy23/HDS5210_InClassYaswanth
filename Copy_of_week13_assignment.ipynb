# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaswanthreddy23/HDS5210_InClassYaswanth/blob/master/Copy_of_week13_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Check in your data file along with this exercise. Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd

# Load the CSV file
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Get the number of rows and columns
rows, columns = data.shape

print(f"The dataset contains {rows} rows and {columns} columns.")
# Out:
# The dataset contains 18025 rows and 12 columns.

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
import pandas as pd

# Load the dataset
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Count unique values in each column
unique_counts = data.nunique()

# Find the column with the greatest number of distinct values
most_diverse_column = unique_counts.idxmax()
most_diverse_count = unique_counts.max()

# Exclude unique identifier columns and find the next most diverse column
# Assuming unique identifier columns might have names like 'ID' or similar
potential_columns = unique_counts[unique_counts < most_diverse_count]
next_most_diverse_column = potential_columns.idxmax()
next_most_diverse_count = potential_columns.max()

# Print results
print("Unique values in each column:")
print(unique_counts)
print(f"\nColumn with the greatest number of distinct values: {most_diverse_column} ({most_diverse_count} unique values)")
print(f"Column with the next most distinct values: {next_most_diverse_column} ({next_most_diverse_count} unique values)")
# Out:
# Unique values in each column:
# Unique ID         18025
# Indicator ID         21
# Name                 18
# Measure               8
# Measure Info          8
# Geo Type Name         5
# Geo Join ID          72
# Geo Place Name      114
# Time Period          55
# Start_Date           43
# Data Value         1147
# Message               0
# dtype: int64
#
# Column with the greatest number of distinct values: Unique ID (18025 unique values)
# Column with the next most distinct values: Data Value (1147 unique values)

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
import pandas as pd

# Load the dataset
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Identify columns where all rows have the same value
constant_columns = [col for col in data.columns if data[col].nunique() == 1]

# Print the result
if constant_columns:
    print("Columns where all rows have the same value:")
    print(constant_columns)
else:
    print("No columns have the same value for every row.")
# Out:
# No columns have the same value for every row.

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Identify numeric columns in the dataset
numeric_columns = data.select_dtypes(include=['number']).columns

# Create a histogram for the first numeric column
if not numeric_columns.empty:
    column_to_plot = numeric_columns[0]  # Use the first numeric column for the histogram
    plt.hist(data[column_to_plot].dropna(), bins=30, edgecolor='black')
    plt.title(f"Distribution of {column_to_plot}")
    plt.xlabel(column_to_plot)
    plt.ylabel("Frequency")
    plt.show()
else:
    print("No numeric columns found in the dataset.")

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)
numeric_columns = data.select_dtypes(include=['number']).columns
if not numeric_columns.empty:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=data[numeric_columns])
    plt.title("Boxplot of Numeric Columns")
    plt.xticks(rotation=45)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Select numeric columns
numeric_columns = data.select_dtypes(include=['number'])

# Check if there are at least two numeric columns
if len(numeric_columns.columns) >= 2:
    # Select the first two numeric columns for the scatterplot
    x_col = numeric_columns.columns[0]
    y_col = numeric_columns.columns[1]

    # Create the scatterplot
    plt.figure(figsize=(8, 6))
    plt.scatter(data[x_col], data[y_col], alpha=0.6, color='green', edgecolor='k')
    plt.title(f"Scatterplot of {x_col} vs {y_col}")
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.grid(alpha=0.3)
    plt.show()
else:
    print("Not enough numeric columns available for a scatterplot.")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Air_Quality.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Identify numeric columns
numeric_columns = data.select_dtypes(include=['number']).columns

# Create a histogram for the second numeric column (if available)
if len(numeric_columns) > 1:
    column_to_plot = numeric_columns[1]  # Select the second numeric column
    plt.figure(figsize=(8, 6))
    plt.hist(data[column_to_plot].dropna(), bins=30, edgecolor='black', alpha=0.7)
    plt.title(f"Histogram of {column_to_plot}")
    plt.xlabel(column_to_plot)
    plt.ylabel("Frequency")
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("No second numeric column found in the dataset.")

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
